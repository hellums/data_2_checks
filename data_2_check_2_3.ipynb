# %% [markdown]
# # Welcome to Knowledge Check 2!
#
# We're going to clean some data today. I would guess about 70% of data science is cleaning and wrangling data, so we want to make sure you can do it. I haven't looked through this data set at all, so we'll see if we can find some issues to clean up. Here's what you need to do to complete the knowledge check:
#
# 1. Make a .py (or .ipynb) file that contains the following (your choice of editor does not matter!) and do the following:
# - find and access a data set in any way you want. You can use an API, a CSV, anything.
# - Fix TWO issues with the data set using techniques you've learned in class. Here are some common fixes:
#   - Remove null values
#   - Fill in null values with 0's or blanks
#   - fill in blanks
#   - fix character strings that aren't formatted correctly (you could use regex for this)
#   - correct column names if they're misnamed
#   - correct spelling (for example, you might have a Country column with an entry that says "Unted States of America".)
#   -  There are hundreds of other things you could fix depending on the issues, so don't worry about whether or not your fix "counts" for the check. It most likely will if you're fixing something.
# 2. Commit your changes.
# 3. Push your changes to your repo and notify your mentor!

# %%
import pandas as pd
import numpy as np
#https://modernthirst.com/home/bourbon-whiskey-mash-bills/

# %%
df = pd.read_csv('mashbills.txt', sep='\t') #5 min

# %%
df.describe()
# Out:
#            Producer                 Label Corn Rye Wheat Barley Char  \
# count           116                   116  114  96    23    114  115
# unique           25                   116   25  25     9     16    9
# top     Heaven Hill  Angel's Envy Bourbon   75  13    20     12   #4
# freq             20                     1   21  13     7     37   42
#
#        Entry Proof
# count          115
# unique          14
# top            125
# freq            46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Producer     116 non-null    object
#  1   Label        116 non-null    object
#  2   Corn         114 non-null    object
#  3   Rye          96 non-null     object
#  4   Wheat        23 non-null     object
#  5   Barley       114 non-null    object
#  6   Char         115 non-null    object
#  7   Entry Proof  115 non-null    object
# dtypes: object(8)
# memory usage: 7.4+ KB

# %%
df.head() #8
# Out:
#        Producer                 Label Corn  Rye Wheat Barley     Char  \
# 0  Angel's Envy  Angel's Envy Bourbon   72   18   NaN     10       #3
# 1       Barrell                Barrel   70   25   NaN      5      NaN
# 2   Barton 1792                  1792  74*  18*   NaN     8*     #3.5
# 3  Brown-Forman        Cooper's Craft   72   18   NaN     10       #4
# 4  Brown-Forman           Early Times   79   11   NaN     10  unknown
#
#   Entry Proof
# 0         125
# 1       121.6
# 2         125
# 3         125
# 4     unknown

# %%
df['Corn'] = df['Corn'].str.replace('*','')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/284817710.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Corn'] = df['Corn'].str.replace('*','')

# %%
df['Rye'] = df['Rye'].str.replace('*','')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/4212814956.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Rye'] = df['Rye'].str.replace('*','')

# %%
df['Wheat'] = df['Wheat'].str.replace('*','')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/2845549307.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Wheat'] = df['Wheat'].str.replace('*','')

# %%
df['Barley'] = df['Barley'].str.replace('*','')  #11
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/318258890.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Barley'] = df['Barley'].str.replace('*','')  #11

# %%
df['Char'] = df['Char'].str.replace('#3/#4','3.5')

# %%
df['Char'] = df['Char'].str.replace('#3','3')

# %%
df['Char'] = df['Char'].str.replace('#4','4')

# %%
df['Char'] = df['Char'].str.replace('#3.5','3.5')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/3256344156.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Char'] = df['Char'].str.replace('#3.5','3.5')

# %%
df['Char'] = df['Char'].str.replace(r'#3 \(5 Gallon\)','3')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/3168779566.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Char'] = df['Char'].str.replace(r'#3 \(5 Gallon\)','3')

# %%
df['Char'] = df['Char'].str.replace(r'#4 \(assumed\)','4')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/3725091911.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Char'] = df['Char'].str.replace(r'#4 \(assumed\)','4')

# %%
df['Char'] = df['Char'].str.replace('#4','4')

# %%
df['Char'] = df['Char'].str.replace('4 \+ Secondary Barrel','4')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/140679071.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Char'] = df['Char'].str.replace('4 \+ Secondary Barrel','4')

# %%
df['Char'] = df['Char'].str.replace('3 \(finished in sherry barrels\)','3')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/3187531551.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Char'] = df['Char'].str.replace('3 \(finished in sherry barrels\)','3')

# %%
df['Char'] = df['Char'].str.replace('3\(Kelvin Cooperage\)','3')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/3429761851.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Char'] = df['Char'].str.replace('3\(Kelvin Cooperage\)','3')

# %%
df['Char'] = df['Char'].str.replace('varies','NaN')

# %%
df['Char'] = df['Char'].str.replace('unknown','NaN')

# %%
df['Char'] = df['Char'].str.replace('#5','5')

# %%
df['Barley'] = df['Barley'].str.replace('5% Barley and Spelt','5')

# %%
df['Rye'] = df['Rye'].str.replace('35% rye & wheat combined','18')

# %%
df['Wheat'] = df['Wheat'].str.replace('35% rye \& wheat combined','17')  #26
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/2673155620.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Wheat'] = df['Wheat'].str.replace('35% rye \& wheat combined','17')  #26

# %%
df['Rye'] = df['Rye'].str.replace('Mix of Bourbon/Rye','32')

# %%
df['Barley'] = df['Barley'].str.replace('Mix of Bourbon/Rye','12')

# %%
df['Corn'] = df['Corn'].str.replace('Mix of Bourbon/Rye','56')

# %%
df['Barley'] = df['Barley'].str.replace('unknown','NaN')

# %%
df['Rye'] = df['Rye'].str.replace('unknown','NaN')

# %%
df['Corn'] = df['Corn'].str.replace('unknown','NaN')

# %%
df['Wheat'] = df['Wheat'].str.replace('unknown','NaN')

# %%
df['Barley'] = df['Barley'].str.replace('unknown','NaN')  #37

# %%
df['Entry Proof'] = df['Entry Proof'].str.replace('unknown','NaN')

# %%
df['Rye'] = df['Rye'].str.replace('<10','6.66')

# %%
df['Rye'] = df['Rye'].str.replace('12-15','13.5')

# %%
df['Rye'] = df['Rye'].str.replace(r' \(Honey Malted barley\)','')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/2778892755.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Rye'] = df['Rye'].str.replace(r' \(Honey Malted barley\)','')

# %%
df['Rye'] = df['Rye'].str.replace(r' + Secondary Toasted Barrel','')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/2536032899.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Rye'] = df['Rye'].str.replace(r' + Secondary Toasted Barrel','')

# %%
df['Entry Proof'] = df['Entry Proof'].str.replace('Unknown','NaN')

# %%
df['Entry Proof'] = df['Entry Proof'].str.replace('110-120','115')

# %%
df['Entry Proof'] = df['Entry Proof'].str.replace('110-115','112.5')  #53

# %%
df['Char'] = df['Char'].str.replace(r' +','')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/2607557928.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Char'] = df['Char'].str.replace(r' +','')

# %%
df['Corn'] = df['Corn'].str.replace(r'Mix of E & B','')

# %%
df['Wheat'] = df['Wheat'].str.replace(r'16\-18','17')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/2150736704.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Wheat'] = df['Wheat'].str.replace(r'16\-18','17')

# %%
df['Entry Proof'] = df['Entry Proof'].str.replace(r'\(lower than their Std proof\)','')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/1502613753.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Entry Proof'] = df['Entry Proof'].str.replace(r'\(lower than their Std proof\)','')

# %%
df['Char'] = df['Char'].str.replace(r'3\+','3')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/1602645761.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Char'] = df['Char'].str.replace(r'3\+','3')

# %%
df['Char'] = df['Char'].str.replace(r'\(assumed\)','')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/825388006.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Char'] = df['Char'].str.replace(r'\(assumed\)','')

# %%
df['Char'] = df['Char'].str.replace(r'\(5Gallon\)','')
# Out:
# C:\Users\Butch\AppData\Local\Temp/ipykernel_37148/3712078284.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Char'] = df['Char'].str.replace(r'\(5Gallon\)','')

# %%
df.to_csv('mashbills.tsv', sep ='\t', index = False)

# %%
df #70
# Out:
#          Producer                       Label Corn  Rye Wheat Barley Char  \
# 0    Angel's Envy        Angel's Envy Bourbon   72   18   NaN     10    3
# 1         Barrell                      Barrel   70   25   NaN      5  NaN
# 2     Barton 1792                        1792   74   18   NaN      8  3.5
# 3    Brown-Forman              Cooper's Craft   72   18   NaN     10    4
# 4    Brown-Forman                 Early Times   79   11   NaN     10  NaN
# ..            ...                         ...  ...  ...   ...    ...  ...
# 111   Wild Turkey             Wild Turkey Rye   37   51   NaN     12    4
# 112       Willett  Bourbon #1 (Old Bardstown)   72   17   NaN     15  NaN
# 113       Willett        Bourbon #4 (Wheated)   65  NaN    20     15  NaN
# 114       Willett                      Rye #1   15   51   NaN     34  NaN
# 115       Willett                      Rye #2   11   74   NaN     15  NaN
#
#     Entry Proof
# 0           125
# 1         121.6
# 2           125
# ...

# %%
# corrected Weller based on Forbes article of original mash bill #80

# %%
df.describe()
# Out:
#            Producer                 Label Corn Rye Wheat Barley Char  \
# count           116                   116  114  96    23    114  115
# unique           25                   116   24  24     9     14    5
# top     Heaven Hill  Angel's Envy Bourbon   75  13    20     12    4
# freq             20                     1   21  13     7     38   44
#
#        Entry Proof
# count          115
# unique          12
# top            125
# freq            46

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Producer     116 non-null    object
#  1   Label        116 non-null    object
#  2   Corn         114 non-null    object
#  3   Rye          96 non-null     object
#  4   Wheat        23 non-null     object
#  5   Barley       114 non-null    object
#  6   Char         115 non-null    object
#  7   Entry Proof  115 non-null    object
# dtypes: object(8)
# memory usage: 7.4+ KB

# %%
df[df['Producer'] == 'Buffalo Trace']
# Out:
#          Producer                 Label Corn   Rye Wheat Barley Char  \
# 16  Buffalo Trace           Ancient Age  NaN  13.5   NaN    NaN    4
# 17  Buffalo Trace           Benchmark 8  NaN  6.66   NaN    NaN    4
# 18  Buffalo Trace              Blantons  NaN  13.5   NaN    NaN    4
# 19  Buffalo Trace         Buffalo Trace  NaN  6.66   NaN    NaN    4
# 20  Buffalo Trace     Col EH Taylor, Jr  NaN  6.66   NaN    NaN    4
# 21  Buffalo Trace           Elmer T Lee  NaN  13.5   NaN    NaN    4
# 22  Buffalo Trace        George T Stagg  NaN  6.66   NaN    NaN    4
# 23  Buffalo Trace       Hancock reserve  NaN  13.5   NaN    NaN    4
# 24  Buffalo Trace           Old Charter  NaN  6.66   NaN    NaN    4
# 25  Buffalo Trace       Rock Hill Farms  NaN  13.5   NaN    NaN    4
# 26  Buffalo Trace              Stagg jr  NaN  6.66   NaN    NaN    4
# 27  Buffalo Trace      Van Winkle (All)  NaN   NaN    17    NaN    4
# 28  Buffalo Trace          Weller (all)   75   NaN    20      5    4
# ...

# %%
df[df['Corn'] < 'NaN'].sort_values(by='Corn', ascending = False)  #does a string sort, as numeric 20 ends up above 120
# Out:
#                             Producer                       Label Corn  Rye  \
# 39          Diageo (with Distillery)   Rhetoric 22, New Bernheim   86    6
# 38          Diageo (with Distillery)  Old Blowhard, Old Bernheim   86    6
# 52   George Dickel Tennessee Whiskey               George Dickel   84    8
# 102                    Smooth Ambler  Old Scout American Whiskey   84    8
# 5                       Brown-Forman              Gentleman Jack   80    8
# ..                               ...                         ...  ...  ...
# 12                      Brown-Forman   Old Forester Straight Rye   15   65
# 15                      Brown-Forman        Woodford Reserve Rye   15   65
# 114                          Willett                      Rye #1   15   51
# 115                          Willett                      Rye #2   11   74
# 51                        Four Roses                Yellow Label       NaN
#
#     Wheat Barley Char Entry Proof
# ...

# %%
df.head(50)
# Out:
#                     Producer  \
# 0               Angel's Envy
# 1                    Barrell
# 2                Barton 1792
# 3               Brown-Forman
# 4               Brown-Forman
# 5               Brown-Forman
# 6               Brown-Forman
# 7               Brown-Forman
# 8               Brown-Forman
# 9               Brown-Forman
# 10              Brown-Forman
# 11              Brown-Forman
# 12              Brown-Forman
# 13              Brown-Forman
# 14              Brown-Forman
# 15              Brown-Forman
# 16             Buffalo Trace
# 17             Buffalo Trace
# 18             Buffalo Trace
# 19             Buffalo Trace
# 20             Buffalo Trace
# 21             Buffalo Trace
# 22             Buffalo Trace
# 23             Buffalo Trace
# 24             Buffalo Trace
# 25             Buffalo Trace
# 26             Buffalo Trace
# 27             Buffalo Trace
# 28             Buffalo Trace
# 29             Buffalo Trace
# 30             Buffalo Trace
# ...

# %%
df["Corn"] = pd.to_numeric(df["Corn"], errors='coerce')
df["Rye"] = pd.to_numeric(df["Rye"], errors='coerce')
df["Wheat"] = pd.to_numeric(df["Wheat"], errors='coerce')
df["Barley"] = pd.to_numeric(df["Barley"], errors='coerce')
df["Char"] = pd.to_numeric(df["Char"], errors='coerce')
df["Entry Proof"] = pd.to_numeric(df["Entry Proof"], errors='coerce')
df.dtypes
# Out:
# Producer        object
# Label           object
# Corn           float64
# Rye            float64
# Wheat          float64
# Barley         float64
# Char           float64
# Entry Proof    float64
# dtype: object

# %%
df.head(10)  #120 (took a while to find the NaN conversion to float method)
# Out:
#        Producer                       Label  Corn   Rye  Wheat  Barley  Char  \
# 0  Angel's Envy        Angel's Envy Bourbon  72.0  18.0    NaN    10.0   3.0
# 1       Barrell                      Barrel  70.0  25.0    NaN     5.0   NaN
# 2   Barton 1792                        1792  74.0  18.0    NaN     8.0   3.5
# 3  Brown-Forman              Cooper's Craft  72.0  18.0    NaN    10.0   4.0
# 4  Brown-Forman                 Early Times  79.0  11.0    NaN    10.0   NaN
# 5  Brown-Forman              Gentleman Jack  80.0   8.0    NaN    12.0   3.0
# 6  Brown-Forman                Jack Daniels  80.0   8.0    NaN    12.0   3.0
# 7  Brown-Forman  Jack Daniels Single Barrel  80.0   8.0    NaN    12.0   3.0
# 8  Brown-Forman            Jack Daniels Rye  18.0  70.0    NaN    12.0   3.0
# 9  Brown-Forman                Old Forester  72.0  18.0    NaN    10.0   4.0
#
#    Entry Proof
# 0        125.0
# 1        121.6
# 2        125.0
# 3        125.0
# 4          NaN
# 5          NaN
# ...

# %%
df.sort_values('Wheat',ascending=False).head(10) #wheated
# Out:
#           Producer                                              Label  Corn  \
# 68     Heaven Hill             Parker's Heritage Wheat Whiskey (2014)  37.0
# 53     Heaven Hill                             Bernheim Wheat Whiskey  37.0
# 56     Heaven Hill                          Elijah Craig Straight Rye  35.0
# 101     Redemption                               Wheated Bourbon, MGP  51.0
# 67     Heaven Hill           Parker's Heritage Collection 4th Edition  68.0
# 89           Luxco                   Rebel Yell (Heaven Hill Sourced)  68.0
# 28   Buffalo Trace                                       Weller (all)  75.0
# 113        Willett                               Bourbon #4 (Wheated)  65.0
# 65     Heaven Hill  Old Fitzgerald 12 Year (Very Special Old Fitzg...  68.0
# 64     Heaven Hill                                     Old Fitzgerald  68.0
#
#      Rye  Wheat  Barley  Char  Entry Proof
# 68   NaN   51.0    12.0   3.0          NaN
# 53   NaN   51.0    12.0   3.0          NaN
# ...

# %%
df.sort_values('Rye',ascending=False).head(10)  #rye-ish
# Out:
#          Producer                      Label  Corn   Rye  Wheat  Barley  Char  \
# 99    Rabbit Hole            Rabbit Hole Rye   NaN  95.0    NaN     5.0   3.0
# 34        Bulleit  Bulleit Rye (MGP Sourced)   NaN  95.0    NaN     5.0   NaN
# 115       Willett                     Rye #2  11.0  74.0    NaN    15.0   NaN
# 8    Brown-Forman           Jack Daniels Rye  18.0  70.0    NaN    12.0   3.0
# 12   Brown-Forman  Old Forester Straight Rye  15.0  65.0    NaN    20.0   4.0
# 15   Brown-Forman       Woodford Reserve Rye  15.0  65.0    NaN    20.0   4.0
# 96       Peerless                Rye Whiskey  31.0  61.0    NaN     8.0   3.0
# 111   Wild Turkey            Wild Turkey Rye  37.0  51.0    NaN    12.0   4.0
# 72    Heaven Hill        Rittenhouse Rye BiB  35.0  51.0    NaN    14.0   3.0
# 71    Heaven Hill            Rittenhouse Rye  35.0  51.0    NaN    14.0   3.0
#
#      Entry Proof
# 99         110.0
# 34           NaN
# 115        110.0
# 8            NaN
# 12           NaN
# ...

# %%
df.to_csv('mashbills.tsv', sep ='\t', index = False)

# %%
df.head(10)
# Out:
#        Producer                       Label  Corn   Rye  Wheat  Barley  Char  \
# 0  Angel's Envy        Angel's Envy Bourbon  72.0  18.0    NaN    10.0   3.0
# 1       Barrell                      Barrel  70.0  25.0    NaN     5.0   NaN
# 2   Barton 1792                        1792  74.0  18.0    NaN     8.0   3.5
# 3  Brown-Forman              Cooper's Craft  72.0  18.0    NaN    10.0   4.0
# 4  Brown-Forman                 Early Times  79.0  11.0    NaN    10.0   NaN
# 5  Brown-Forman              Gentleman Jack  80.0   8.0    NaN    12.0   3.0
# 6  Brown-Forman                Jack Daniels  80.0   8.0    NaN    12.0   3.0
# 7  Brown-Forman  Jack Daniels Single Barrel  80.0   8.0    NaN    12.0   3.0
# 8  Brown-Forman            Jack Daniels Rye  18.0  70.0    NaN    12.0   3.0
# 9  Brown-Forman                Old Forester  72.0  18.0    NaN    10.0   4.0
#
#    Entry Proof
# 0        125.0
# 1        121.6
# 2        125.0
# 3        125.0
# 4          NaN
# 5          NaN
# ...

# %%
bourbon_list = df[['Producer', 'Label']]
print(bourbon_list)  #print to identify favorites on list for ML
# Out:
#          Producer                       Label
# 0    Angel's Envy        Angel's Envy Bourbon
# 1         Barrell                      Barrel
# 2     Barton 1792                        1792
# 3    Brown-Forman              Cooper's Craft
# 4    Brown-Forman                 Early Times
# ..            ...                         ...
# 111   Wild Turkey             Wild Turkey Rye
# 112       Willett  Bourbon #1 (Old Bardstown)
# 113       Willett        Bourbon #4 (Wheated)
# 114       Willett                      Rye #1
# 115       Willett                      Rye #2
#
# [116 rows x 2 columns]

# %%
df20 = pd.read_csv('metacritic.txt', sep='\t') #5 min

# %%
df20.head()
# Out:
#                                       Bourbon  Meta Critic  STDEV  Reviewers  \
# 0  Ancient Age 10yo Kentucky Straight Bourbon         8.44   0.35          8
# 1       Ancient Age Kentucky Straight Bourbon         7.85   0.69         10
# 2        Angel's Envy Bourbon (Port-finished)         8.42   0.47         18
# 3                  Angel's Envy Cask Strength         8.85   0.48         12
# 4           Baker's 7yo Single Barrel Bourbon         9.02   0.26          3
#
#    Cost         Class  Super Cluster Cluster Country     Type
# 0   1.0  Bourbon-like            NaN      R2     USA  Bourbon
# 1   1.0  Bourbon-like            NaN      R2     USA  Bourbon
# 2   3.0  Bourbon-like            NaN      R2     USA  Bourbon
# 3   5.5  Bourbon-like            NaN      R2     USA  Bourbon
# 4   3.0  Bourbon-like            NaN      R2     USA  Bourbon

# %%
df20.drop(['STDEV', 'Class', 'Super Cluster', 'Cluster', 'Country', 'Type'], axis=1, inplace=True)

# %%
df20.head(10)
# Out:
#                                           Bourbon  Meta Critic  Reviewers  \
# 0      Ancient Age 10yo Kentucky Straight Bourbon         8.44          8
# 1           Ancient Age Kentucky Straight Bourbon         7.85         10
# 2            Angel's Envy Bourbon (Port-finished)         8.42         18
# 3                      Angel's Envy Cask Strength         8.85         12
# 4               Baker's 7yo Single Barrel Bourbon         9.02          3
# 5                 Baker's 7yo Small Batch Bourbon         8.73         25
# 6  Barrell 15yo Craft Spirits Bourbon (Batch 001)         8.81          4
# 7                   Barrell Bourbon (all Batches)         8.79         16
# 8                  Barton 1792 Full Proof Bourbon         8.66         13
# 9                    Barton 1792 High Rye Bourbon         8.69          6
#
#    Cost
# 0   1.0
# 1   1.0
# 2   3.0
# 3   5.5
# 4   3.0
# 5   3.0
# 6   5.5
# 7   4.0
# 8   3.0
# 9   3.0

# %%
df20.describe()
# Out:
#        Meta Critic   Reviewers        Cost
# count   176.000000  176.000000  176.000000
# mean      8.553864   12.278409    3.281250
# std       0.379586    7.572642    1.437911
# min       7.090000    3.000000    1.000000
# 25%       8.347500    5.000000    2.000000
# 50%       8.600000   11.000000    3.000000
# 75%       8.810000   18.000000    4.000000
# max       9.300000   31.000000    5.500000

# %%
df20
# Out:
#                                         Bourbon  Meta Critic  Reviewers  Cost
# 0    Ancient Age 10yo Kentucky Straight Bourbon         8.44          8   1.0
# 1         Ancient Age Kentucky Straight Bourbon         7.85         10   1.0
# 2          Angel's Envy Bourbon (Port-finished)         8.42         18   3.0
# 3                    Angel's Envy Cask Strength         8.85         12   5.5
# 4             Baker's 7yo Single Barrel Bourbon         9.02          3   3.0
# ..                                          ...          ...        ...   ...
# 171            Yellowstone 2015 Limited Edition         8.34          4   5.0
# 172            Yellowstone 2016 Limited Edition         8.71          3   5.0
# 173            Yellowstone 2018 Limited Edition         8.82          3   5.0
# 174  Yellowstone Limited Edition (all vintages)         8.71          3   5.0
# 175                          Yellowstone Select         8.23          9   3.0
#
# [176 rows x 4 columns]

# %%
df20.sort_values('Meta Critic',ascending=False).head(10)  #rockstars
# Out:
#                                           Bourbon  Meta Critic  Reviewers  \
# 159            Willett Family Estate 22yo Bourbon         9.30          4
# 112  Pappy Van Winkle Family Reserve Bourbon 15yo         9.22         14
# 55                                 George T Stagg         9.20         31
# 113  Pappy Van Winkle Family Reserve Bourbon 20yo         9.19         17
# 168                          William Larue Weller         9.18         22
# 39                              Elijah Craig 21yo         9.17          6
# 145              Wild Turkey 15yo American Spirit         9.15          3
# 160            Willett Family Estate 24yo Bourbon         9.15          3
# 94           Michter's 20yo Single Barrel Bourbon         9.14          7
# 136                Stagg Jr batch 9 (131.9 proof)         9.10          5
#
#      Cost
# 159   5.5
# 112   5.5
# 55    5.5
# 113   5.5
# 168   5.5
# 39    5.5
# 145   5.5
# 160   5.5
# 94    5.5
# 136   4.0

# %%
df20.sort_values('Cost',ascending=False).head(10)  #unobtainium
# Out:
#                                   Bourbon  Meta Critic  Reviewers  Cost
# 71   Jefferson's 18yo Presidential Select         8.81         10   5.5
# 156    Willett Family Estate 13yo Bourbon         9.02          5   5.5
# 39                      Elijah Craig 21yo         9.17          6   5.5
# 167                William Heavenhill BiB         8.98          6   5.5
# 168                  William Larue Weller         9.18         22   5.5
# 34                        Eagle Rare 17yo         8.88         18   5.5
# 145      Wild Turkey 15yo American Spirit         9.15          3   5.5
# 160    Willett Family Estate 24yo Bourbon         9.15          3   5.5
# 159    Willett Family Estate 22yo Bourbon         9.30          4   5.5
# 158    Willett Family Estate 17yo Bourbon         8.92          3   5.5

# %%
df20.sort_values('Reviewers',ascending=False).head(10)  #most reviewed
# Out:
#                                       Bourbon  Meta Critic  Reviewers  Cost
# 55                             George T Stagg         9.20         31   5.5
# 28                            Bulleit Bourbon         8.33         29   2.0
# 92                               Maker's Mark         8.19         29   2.0
# 22                      Buffalo Trace Bourbon         8.55         29   2.0
# 21      Booker's Small Batch Straight Bourbon         8.76         29   3.0
# 33                            Eagle Rare 10yo         8.64         29   2.0
# 37                          Elijah Craig 12yo         8.66         27   2.0
# 87         Knob Creek Small Batch 9yo Bourbon         8.59         27   2.0
# 18   Blanton's Original Bourbon Single Barrel         8.65         27   3.0
# 143                   Wild Turkey 101 Bourbon         8.45         27   2.0

# %% [markdown]
# # Welcome to Knowledge Check 3!
#
# Today we're going to combine some data.
#
# ## Combining Data
#
# Data taken from [Louisville Metro Data](https://data.louisvilleky.gov/dataset/parking-citations). This is the same data from Knowledge Check 2, but we're going to pull in a table of codes to try to see what these parking tickets mean. At the bottom of the page, you can see a csv titled ```Violation Codes``` - it's fairly common to see a data set up like this, where you have the codes in one table (or file) and the description of them in another. For exampe, at Humana, we have a table that has CPT Code information, like descriptions of the type of surgery, and then on the claims table we just have the CPT code (this is just a code for what surgery was performed). I routinely have to just join these together and pull the codes and claims from one table and descriptions from another.
#
# ---
#
# 1. Make a .py (or .ipynb) file that contains the following (your choice of editor does not matter!) and do the following:
# - import two sets of data from any source you want. They can be typed by hand like I did below, imported from an API, or any other way.
# - join them / combine them into one data frame. You can use any kind of join you want, but I find inner joins and left joins are the most common by far. Play around with different types though if you want to see what they do.
# 2. Commit your changes.
# 3. Push your changes to your repo and notify your mentor!

# %%
df20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Bourbon      176 non-null    object
#  1   Meta Critic  176 non-null    float64
#  2   Reviewers    176 non-null    int64
#  3   Cost         176 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 5.6+ KB

# %%
df.to_csv('mashbills.tsv', sep ='\t', index = False)

# %%
df20.to_csv('metacritic.tsv', sep ='\t', index = False)

# %%
df21 = pd.read_csv('metacritic2.tsv', sep='\t') #5 min

# %%
newdf = df.merge(df21)  # (only bourbons that are in both datasets, mashbill and metacritic score)

# %%
newdf
# Out:
#                            Producer                             Label  Corn  \
# 0                      Angel's Envy              Angel's Envy Bourbon  72.0
# 1                           Barrell                            Barrel  70.0
# 2                       Barton 1792                              1792  74.0
# 3                      Brown-Forman                       Early Times  79.0
# 4                      Brown-Forman                    Gentleman Jack  80.0
# 5                      Brown-Forman        Jack Daniels Single Barrel  80.0
# 6                      Brown-Forman                      Old Forester  72.0
# 7                      Brown-Forman                 Old Forester 1870  72.0
# 8                      Brown-Forman                 Old Forester 1897  72.0
# 9                      Brown-Forman             Woodford Double Oaked  72.0
# 10                     Brown-Forman                  Woodford Reserve  72.0
# ...

# %%
newdf.to_csv('mashbill_rated.tsv', sep ='\t', index = False)

# %%
newdf.sort_values('Meta Critic',ascending=False).head(10)  #survey says!?
# Out:
#          Producer                      Label  Corn    Rye  Wheat  Barley  \
# 16  Buffalo Trace             George T Stagg   NaN   6.66    NaN     NaN
# 32       Jim Beam                    Baker's  75.0  13.00    NaN    12.0
# 18  Buffalo Trace           Van Winkle (All)   NaN    NaN   17.0     NaN
# 27    Heaven Hill  Elijah Craig Barrel Proof  78.0  10.00    NaN    12.0
# 14  Buffalo Trace          Col EH Taylor, Jr   NaN   6.66    NaN     NaN
# 1         Barrell                     Barrel  70.0  25.00    NaN     5.0
# 34       Jim Beam                   Booker's  75.0  13.00    NaN    12.0
# 38       Jim Beam                 Knob Creek  75.0  13.00    NaN    12.0
# 15  Buffalo Trace                Elmer T Lee   NaN  13.50    NaN     NaN
# 49    Wild Turkey                 Rare Breed  75.0  13.00    NaN    12.0
#
#     Char  Entry Proof  Meta Critic  Reviewers  Cost
# 16   4.0        125.0         9.20         31   5.5
# 32   4.0          NaN         9.02          3   3.0
# ...

# %%
newdf.sort_values('Cost',ascending=False).head(10)  #unobtainium
# Out:
#          Producer                            Label  Corn    Rye  Wheat  \
# 18  Buffalo Trace                 Van Winkle (All)   NaN    NaN   17.0
# 16  Buffalo Trace                   George T Stagg   NaN   6.66    NaN
# 27    Heaven Hill        Elijah Craig Barrel Proof  78.0  10.00    NaN
# 43   Maker's Mark             Makers Cask Strength  70.0    NaN   16.0
# 17  Buffalo Trace                         Stagg jr   NaN   6.66    NaN
# 1         Barrell                           Barrel  70.0  25.00    NaN
# 14  Buffalo Trace                Col EH Taylor, Jr   NaN   6.66    NaN
# 9    Brown-Forman            Woodford Double Oaked  72.0  18.00    NaN
# 23        Bulleit  Bulleit Barrel Strength Bourbon  68.0  28.00    NaN
# 45      Michter's            Michter's Toasted Oak  79.0  11.00    NaN
#
#     Barley  Char  Entry Proof  Meta Critic  Reviewers  Cost
# 18     NaN   4.0        114.0         8.90         15   5.5
# 16     NaN   4.0        125.0         9.20         31   5.5
# ...

# %%
newdf.sort_values('Reviewers',ascending=False).head(10)  #popularity contest
# Out:
#          Producer             Label  Corn    Rye  Wheat  Barley  Char  \
# 16  Buffalo Trace    George T Stagg   NaN   6.66    NaN     NaN   4.0
# 13  Buffalo Trace     Buffalo Trace   NaN   6.66    NaN     NaN   4.0
# 21        Bulleit   Bulleit Bourbon  68.0  28.00    NaN     4.0   NaN
# 20  Buffalo Trace        Eagle Rare   NaN   6.66    NaN     NaN   4.0
# 44   Maker's Mark       Makers Mark  70.0    NaN   16.0    14.0   NaN
# 34       Jim Beam          Booker's  75.0  13.00    NaN    12.0   4.0
# 12  Buffalo Trace          Blantons   NaN  13.50    NaN     NaN   4.0
# 42   Maker's Mark         Makers 46  70.0    NaN   16.0    14.0   NaN
# 49    Wild Turkey        Rare Breed  75.0  13.00    NaN    12.0   4.0
# 10   Brown-Forman  Woodford Reserve  72.0  18.00    NaN    10.0   4.0
#
#     Entry Proof  Meta Critic  Reviewers  Cost
# 16        125.0         9.20         31   5.5
# 13        125.0         8.55         29   2.0
# 21          NaN         8.33         29   2.0
# ...

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54 entries, 0 to 53
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Producer     54 non-null     object
#  1   Label        54 non-null     object
#  2   Corn         44 non-null     float64
#  3   Rye          42 non-null     float64
#  4   Wheat        11 non-null     float64
#  5   Barley       44 non-null     float64
#  6   Char         42 non-null     float64
#  7   Entry Proof  41 non-null     float64
#  8   Meta Critic  54 non-null     float64
#  9   Reviewers    54 non-null     int64
#  10  Cost         54 non-null     float64
# dtypes: float64(8), int64(1), object(2)
# memory usage: 5.1+ KB

# %%
newdf[newdf['Producer'] == 'Willett']
# Out:
#    Producer                 Label  Corn  Rye  Wheat  Barley  Char  \
# 53  Willett  Bourbon #4 (Wheated)  65.0  NaN   20.0    15.0   NaN
#
#     Entry Proof  Meta Critic  Reviewers  Cost
# 53        115.0         8.54         13   3.0

# %%
newdf[newdf['Label'] == 'Bourbon #4 (Wheated)']
# Out:
#    Producer                 Label  Corn  Rye  Wheat  Barley  Char  \
# 53  Willett  Bourbon #4 (Wheated)  65.0  NaN   20.0    15.0   NaN
#
#     Entry Proof  Meta Critic  Reviewers  Cost
# 53        115.0         8.54         13   3.0

# %%
newdf[newdf['Label'] == 'Makers 46']
# Out:
#         Producer      Label  Corn  Rye  Wheat  Barley  Char  Entry Proof  \
# 42  Maker's Mark  Makers 46  70.0  NaN   16.0    14.0   NaN        110.0
#
#     Meta Critic  Reviewers  Cost
# 42         8.61         25   3.0

# %%
newdf[newdf['Label'] == 'Russels\' Reserve']
# Out:
#        Producer             Label  Corn   Rye  Wheat  Barley  Char  \
# 50  Wild Turkey  Russels' Reserve  75.0  13.0    NaN    12.0   4.0
#
#     Entry Proof  Meta Critic  Reviewers  Cost
# 50        114.0         8.57         20   2.0

# %%
newdf[newdf['Label'] == 'Makers Mark']
# Out:
#         Producer        Label  Corn  Rye  Wheat  Barley  Char  Entry Proof  \
# 44  Maker's Mark  Makers Mark  70.0  NaN   16.0    14.0   NaN        110.0
#
#     Meta Critic  Reviewers  Cost
# 44         8.19         29   2.0

# %%
newdf[newdf['Label'] == 'Knob Creek']
# Out:
#     Producer       Label  Corn   Rye  Wheat  Barley  Char  Entry Proof  \
# 38  Jim Beam  Knob Creek  75.0  13.0    NaN    12.0   4.0        125.0
#
#     Meta Critic  Reviewers  Cost
# 38         8.76         19   3.0

# %%
newdf[newdf['Label'] == 'Eagle Rare']
# Out:
#          Producer       Label  Corn   Rye  Wheat  Barley  Char  Entry Proof  \
# 20  Buffalo Trace  Eagle Rare   NaN  6.66    NaN     NaN   4.0        125.0
#
#     Meta Critic  Reviewers  Cost
# 20         8.64         29   2.0

# %%
#newdf[newdf['Barley'] < 10] 
dfQuery = newdf.query('Barley >= 12 or Rye >= 12')
print ('\n Query:\n ',dfQuery)
# Out:
#  Query:
#            Producer                             Label  Corn   Rye  Wheat  \
# 0    Angel's Envy              Angel's Envy Bourbon  72.0  18.0    NaN
# 1         Barrell                            Barrel  70.0  25.0    NaN
# 2     Barton 1792                              1792  74.0  18.0    NaN
# 4    Brown-Forman                    Gentleman Jack  80.0   8.0    NaN
# 5    Brown-Forman        Jack Daniels Single Barrel  80.0   8.0    NaN
# 6    Brown-Forman                      Old Forester  72.0  18.0    NaN
# 7    Brown-Forman                 Old Forester 1870  72.0  18.0    NaN
# 8    Brown-Forman                 Old Forester 1897  72.0  18.0    NaN
# 9    Brown-Forman             Woodford Double Oaked  72.0  18.0    NaN
# 10   Brown-Forman                  Woodford Reserve  72.0  18.0    NaN
# 11  Buffalo Trace                       Ancient Age   NaN  13.5    NaN
# 12  Buffalo Trace                          Blantons   NaN  13.5    NaN
# ...

# %%
newdf.sort_values('Entry Proof',ascending=False)  #survey says!?
# Out:
#                            Producer                             Label  Corn  \
# 0                      Angel's Envy              Angel's Envy Bourbon  72.0
# 20                    Buffalo Trace                        Eagle Rare   NaN
# 41                            Luxco  Rebel Yell (Heaven Hill Sourced)  68.0
# 40                            Luxco                       Ezra Brooks  78.0
# 38                         Jim Beam                        Knob Creek  75.0
# 37                         Jim Beam            Jim Beam Single Barrel  75.0
# 36                         Jim Beam               Jim Beam Double Oak  75.0
# 35                         Jim Beam                          Jim Beam  75.0
# 34                         Jim Beam                          Booker's  75.0
# 31                      Jefferson's                    Ocean, Unknown   NaN
# 30                      Heaven Hill                    Old Fitzgerald  68.0
# ...

# %%
newdf
# Out:
#                            Producer                             Label  Corn  \
# 0                      Angel's Envy              Angel's Envy Bourbon  72.0
# 1                           Barrell                            Barrel  70.0
# 2                       Barton 1792                              1792  74.0
# 3                      Brown-Forman                       Early Times  79.0
# 4                      Brown-Forman                    Gentleman Jack  80.0
# 5                      Brown-Forman        Jack Daniels Single Barrel  80.0
# 6                      Brown-Forman                      Old Forester  72.0
# 7                      Brown-Forman                 Old Forester 1870  72.0
# 8                      Brown-Forman                 Old Forester 1897  72.0
# 9                      Brown-Forman             Woodford Double Oaked  72.0
# 10                     Brown-Forman                  Woodford Reserve  72.0
# ...

# %%
df.head()
# Out:
#        Producer                 Label  Corn   Rye  Wheat  Barley  Char  \
# 0  Angel's Envy  Angel's Envy Bourbon  72.0  18.0    NaN    10.0   3.0
# 1       Barrell                Barrel  70.0  25.0    NaN     5.0   NaN
# 2   Barton 1792                  1792  74.0  18.0    NaN     8.0   3.5
# 3  Brown-Forman        Cooper's Craft  72.0  18.0    NaN    10.0   4.0
# 4  Brown-Forman           Early Times  79.0  11.0    NaN    10.0   NaN
#
#    Entry Proof
# 0        125.0
# 1        121.6
# 2        125.0
# 3        125.0
# 4          NaN

# %%
# %matplotlib inline
df = newdf
df.plot(kind='box', rot=90);

# %%
df.Corn.plot(kind='kde', title='Corn Density');

# %%
df.plot.scatter(x='Cost', y='Meta Critic', title='Scatter (Cost vs Score)');

# %%
df.rename(columns = {'Meta Critic':'Score', 'Entry Proof':'Entry_Proof'}, inplace = True)

# %%
df.groupby('Producer').Score.mean()
# Out:
# Producer
# Angel's Envy                       8.420000
# Barrell                            8.790000
# Barton 1792                        8.660000
# Brown-Forman                       8.373750
# Buffalo Trace                      8.641000
# Bulleit                            8.463333
# George Dickel Tennessee Whiskey    8.190000
# Heaven Hill                        8.476667
# Jefferson's                        8.400000
# Jim Beam                           8.430000
# Luxco                              8.095000
# Maker's Mark                       8.506667
# Michter's                          8.415000
# Smooth Ambler                      8.190000
# Wild Turkey                        8.445000
# Willett                            8.540000
# Name: Score, dtype: float64

# %%
df.groupby('Producer').Score.mean().plot(rot=90);
